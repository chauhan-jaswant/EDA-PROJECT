# %% [markdown]
# <a href="https://colab.research.google.com/github/chauhan-jaswant/EDA-PROJECT/blob/main/Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA Project
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Hi everyone,**
#
# This is my first EDA project .In this project we well analysis play store app review by useing some dictory like numpy , pandas,matplotlib.pyplot,Datetime etc.
#
# The Play Store apps data has enormous potential to drive app-making businesses to success.
#
# Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
#
# We will do a comprehensive analysis of the android app market by comparing over ten thousand apps in google play across different categories.
#
# The data are given in below two file:
#
# 1.**playstore data.csv:**In this file we have 10842 rows and thirteen
# columns.These thirteen columns show the type of app,the Category of these app,Rating & Reviews of given apps,also the size of apps and how many people have Installed these apps,the last Updated of these apps and the Current Ver of these app etc.
#
#
# 2.**user_reviews.csv:**In this file we have many review  for each app also provide the Sentiment in the form of positive,negative & Neutral.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### **1)What is the ratio of number of Paid apps and Free apps?**
# #### **2)Which category of Apps from the Content Rating column are found more on playstore ?**
# ####**3)Top categories on Google Playstore?**
# ####**4)Which category App's have most number of installs?**
# #### **5)what Average rating of the apps?**
# ####**6)What are the Top 10 installed apps in any category?**
# ####**7)How many Top apps that are of free type?**
# ####**8)What is the percentage of review sentiments?**
# ####**9)Show how many Apps with the highest number of positive reviews?**
# ####**10)Show how many Apps with the highest number of negative reviews?**
# ####**11) Show the Distribution of App update over the Year?**
# ####**12)How is sentiment polarity varying for paid and free apps?**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
from datetime import datetime
# plotly
import plotly 
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import warnings
#sns.set(font_scale=1.5)
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/almabetter assignments/EDA project/Play Store Data.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

Number_of_Row=df.shape[0]
Number_of_columns=df.shape[1]

# %%
Number_of_Row
# Out:
# 10841

# %%
Number_of_columns
# Out:
# 13

# %%
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values/Missing Values/Null Values

# %%
# Dataset Duplicate Values/Missing Values/Null Values Count
Dataset=pd.DataFrame(index=df.columns)
Dataset['datatype']=df.dtypes
# Pandas dataframe.count() is used to count the no. of non-NA/null observations across the given axis. It works with non-floating type data as well.
Dataset['non_null_valus']=df.count()
Dataset['null_values']=df.isnull().sum()
Dataset["unique count"]=df.nunique()
Dataset
# Out:
#                datatype  non_null_valus  null_values  unique count
# App              object           10841            0          9660
# Category         object           10841            0            34
# Rating          float64            9367         1474            40
# Reviews          object           10841            0          6002
# Size             object           10841            0           462
# Installs         object           10841            0            22
# Type             object           10840            1             3
# Price            object           10841            0            93
# Content Rating   object           10840            1             6
# Genres           object           10841            0           120
# Last Updated     object           10841            0          1378
# Current Ver      object           10833            8          2832
# Android Ver      object           10838            3            33

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In above dataset Rating has 1474 null values and Type has 1 null value and Content Rating has 1 null values also current Ver has 8 null values and androis ver has 3 null values.

# %%
# isnull() return a boolean same-sized object indicating if the values are NA.
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
# Drop the NaN values in Rating columns .
df.dropna(subset=['Rating'],inplace=True)

# %%
# Afer droping NaN value check the shape of 'Rating' column.
df['Rating'].shape
# Out:
# (9367,)

# %%
# sns.distplot(df['Rating'],color='firebrick')

fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(df['Rating'],color='firebrick',ax=ax[0])
sns.boxplot(x='Rating',data=df, ax=ax[1])
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# *   After removing NaN values the average rating comes to be 4.2 as  show in above plotes.

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.dropna(subset=['Content Rating'],inplace=True)

# %%
df['Content Rating'].shape
# Out:
# (9366,)

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                   App            Category  Rating Reviews  \
# 15    Learn To Draw Kawaii Characters      ART_AND_DESIGN     3.2      55
# 1553             Market Update Helper  LIBRARIES_AND_DEMO     4.1   20145
# 6322           Virtual DJ Sound Mixer               TOOLS     4.2    4010
# 7333                      Dots puzzle              FAMILY     4.0     179
#
#       Size    Installs  Type  Price Content Rating            Genres  \
# 15    2.7M      5,000+  Free      0       Everyone      Art & Design
# 1553   11k  1,000,000+  Free      0       Everyone  Libraries & Demo
# 6322  8.7M    500,000+  Free      0       Everyone             Tools
# 7333   14M     50,000+  Paid  $0.99       Everyone            Puzzle
#
#            Last Updated Current Ver Android Ver
# 15         June 6, 2018         NaN  4.2 and up
# 1553  February 12, 2013         NaN  1.5 and up
# 6322       May 10, 2017         NaN  4.0 and up
# 7333     April 18, 2018         NaN  4.0 and up

# %%
df.dropna(subset=['Current Ver'],inplace=True)

# %%
df['Current Ver'].shape
# Out:
# (9362,)

# %%
df[df['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
df.dropna(subset=['Android Ver'],inplace=True)

# %%
df['Android Ver'].shape
# Out:
# (9360,)

# %%
df.reset_index()
# Out:
#       index                                                App  \
# 0         0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         1                                Coloring book moana
# 2         2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         3                              Sketch - Draw & Paint
# 4         4              Pixel Draw - Number Art Coloring Book
# ...     ...                                                ...
# 9355  10834                                      FR Calculator
# 9356  10836                                   Sya9a Maroc - FR
# 9357  10837                   Fr. Mike Schmitz Audio Teachings
# 9358  10839                      The SCP Foundation DB fr nn5n
# 9359  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews                Size     Installs  \
# 0          ART_AND_DESIGN     4.1     159                 19M      10,000+
# ...

# %% [markdown]
# ### Check the duplicate element in app columns and after that drop the duplicate element

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.drop_duplicates(subset = 'App', inplace = True)
df.shape
# Out:
# (8190, 13)

# %%
df[df['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up

# %% [markdown]
# ####We have successfully handled all the duplicate values  in the App column and all NaN values in all columns The resultant number of rows after droping the duplicate values in app columns and NaN values in all columns come out to be 8190.

# %% [markdown]
# *  Now Change the DataType of Last Updated column.

# %%
df["Last Updated"] = pd.to_datetime(df['Last Updated'])
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Last Updated'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Last Updated
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 128.0 KB

# %%
df['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   object
# dtypes: object(1)
# memory usage: 128.0+ KB

# %% [markdown]
# * Change the datatype of price. it convert into float.

# %%
def remove_dollar(val):

  if '$' in val:
    return float(val[1:])
  else:
    return float(val)

df['Price']=df['Price'].apply(lambda x: remove_dollar(x))
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   float64
# dtypes: float64(1)
# memory usage: 128.0 KB

# %% [markdown]
# *   Change the datatype of installs columns into integer.
# *   for this firestly remove the + and , sign in each element of installs columns

# %%
df['Installs'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   object
# dtypes: object(1)
# memory usage: 128.0+ KB

# %%
def new_values(val):
  '''
  This function drops the + symbol if present and returns the value with int datatype.
  '''
  if '+' and ',' in val:
    new = int(val[:-1].replace(',',''))
    return new
  elif '+' in val:
    new1 = int(val[:-1])
    return new1
  else:
    return int(val)

df['Installs'] = df['Installs'].apply(lambda x: new_values(x))
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159   19M     10000  Free    0.0       Everyone
# 1     967   14M    500000  Free    0.0       Everyone
# 2   87510  8.7M   5000000  Free    0.0       Everyone
# 3  215644   25M  50000000  Free    0.0           Teen
# 4     967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Installs'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   int64
# dtypes: int64(1)
# memory usage: 128.0 KB

# %% [markdown]
# * Convert the datatype of size columns into float .
# * Here convert the M in Mb and  the k into Mb and 'Varies with device' into NaN value.

# %%
df['Size'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8190 entries, 0 to 10840
# Series name: Size
# Non-Null Count  Dtype
# --------------  -----
# 8190 non-null   object
# dtypes: object(1)
# memory usage: 128.0+ KB

# %%
def convert_values(val):
  '''
  This function converts all the valid entries in KB to MB and returns the result in float datatype.
  '''
  try:
    if 'M' in val:
      return float(val[:-1])
    elif 'k' in val:
      return round(float(val[:-1])/1024, 4)
    elif  'Varies with device' in val:
       pass
    else:
      return val
  except:
    return val

df['Size'] = df['Size'].apply(lambda x: convert_values(x))
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159  19.0     10000  Free    0.0       Everyone
# 1     967  14.0    500000  Free    0.0       Everyone
# 2   87510   8.7   5000000  Free    0.0       Everyone
# 3  215644  25.0  50000000  Free    0.0           Teen
# 4     967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
#Drop the NaN values in Size columns:
df.dropna(subset='Size',inplace=True)

# %%
#Reset the index number:
df=df.reset_index()

# %%
df.head()
# Out:
#    index                                                App        Category  \
# 0      0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1      1                                Coloring book moana  ART_AND_DESIGN
# 2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3      3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4      4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating Reviews  Size  Installs  Type  Price Content Rating  \
# 0     4.1     159  19.0     10000  Free    0.0       Everyone
# 1     3.9     967  14.0    500000  Free    0.0       Everyone
# 2     4.7   87510   8.7   5000000  Free    0.0       Everyone
# 3     4.5  215644  25.0  50000000  Free    0.0           Teen
# 4     4.3     967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
max_value=df['Size'].max()
min_value=df['Size'].min()
mean_value=df['Size'].mean()
median_value=df['Size'].median()
print(f'The size columns max_value:{max_value},min_value:{min_value},mean_value:{mean_value} and median_value:{median_value}')
# Out:
# The size columns max_value:100.0,min_value:0.0083,mean_value:21.7671655319755 and median_value:13.0

# %% [markdown]
# **Visualization  of `**Size**` using displot and detecting the outliers through boxplot.**

# %%
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(df['Size'], color='orange', ax=ax[0])
sns.boxplot(x='Size',data=df, ax=ax[1])
# Out:
# <Axes: xlabel='Size'>

# %% [markdown]
# * It is clear from the visualizations that the data in the **Size** column is skewed towards the right.

# %% [markdown]
# *  Convert the Datatype of reviews into string to int.

# %%
df['Reviews'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7021 entries, 0 to 7020
# Series name: Reviews
# Non-Null Count  Dtype
# --------------  -----
# 7021 non-null   object
# dtypes: object(1)
# memory usage: 55.0+ KB

# %%
df['Reviews'] = df['Reviews'].astype(int)
df['Reviews'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7021 entries, 0 to 7020
# Series name: Reviews
# Non-Null Count  Dtype
# --------------  -----
# 7021 non-null   int64
# dtypes: int64(1)
# memory usage: 55.0 KB

# %%
df.describe()
# Out:
#               index       Rating       Reviews         Size      Installs  \
# count   7021.000000  7021.000000  7.021000e+03  7021.000000  7.021000e+03
# mean    5638.433984     4.160704  1.448960e+05    21.767166  4.471804e+06
# std     3079.108366     0.559241  1.024428e+06    22.731638  2.714908e+07
# min        0.000000     1.000000  1.000000e+00     0.008300  1.000000e+00
# 25%     3087.000000     4.000000  8.400000e+01     4.900000  1.000000e+04
# 50%     5716.000000     4.300000  1.546000e+03    13.000000  1.000000e+05
# 75%     8292.000000     4.500000  2.658700e+04    31.000000  1.000000e+06
# max    10840.000000     5.000000  4.489172e+07   100.000000  1.000000e+09
#
#              Price
# count  7021.000000
# mean      1.174222
# std      18.205355
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     400.000000

# %% [markdown]
# ##Data Exploration :by using pair plot
# **Pair plot** is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters.

# %%
Rating = df['Rating']
Size = df['Size']
Installs = df['Installs']
Reviews = df['Reviews']
Type = df['Type']
Price =df['Price']

p = sns.pairplot(pd.DataFrame(list(zip(Rating, Size, np.log(Installs), np.log10(Reviews), Price, Type)), 
                        columns=['Rating','Size', 'Installs', 'Reviews', 'Price','Type']), hue='Type')
p.fig.suptitle("Pairwise Plot - Rating, Size, Installs, Reviews, Price",x=0.5, y=1.0, fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pairwise Plot - Rating, Size, Installs, Reviews, Price')

# %% [markdown]
# * Most of the App are Free.
# * Most of the Paid Apps have Rating around 4
# * As the number of installation increases the number of reviews of the particaular app also increases.

# %% [markdown]
# ##Now Exploring User_review data

# %%
# Reading the userreviews.csv file
file_path = '/content/drive/MyDrive/Colab Notebooks/almabetter assignments/EDA project/User Reviews (1).csv'
ur_df=pd.read_csv(file_path)

# %%
ur_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
ur_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
Number_of_Row=ur_df.shape[0]
Number_of_columns=ur_df.shape[1]

# %%
Number_of_Row
# Out:
# 64295

# %%
Number_of_columns
# Out:
# 5

# %%
print(ur_df.columns)
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# **first define the information of  the columns contain**
#
# user_reviews dataframe has 5 columns. The 5 columns are identified as follows:
#
# * **App:** Contains the name of the app with a short description .
# * **Translated_Review:** It contains the English translation of the review dropped by the user of the app.
# * **Sentiment:** It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
# * **Sentiment_Polarity:** It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
# * **Sentiment_Subjectivity:** This value gives how close a reviewers opinion is to the opinion of the general public. Its range is [0,1].

# %%
column_description=pd.DataFrame(index=ur_df.columns)
column_description["datatype"]=ur_df.dtypes
column_description["not null values"]=ur_df.count()
column_description["null value"]=ur_df.isnull().sum()
column_description["unique count"]=ur_df.nunique()
column_description
# Out:
#                        datatype  not null values  null value  unique count
# App                      object            64295           0          1074
# Translated_Review        object            37427       26868         27994
# Sentiment                object            37432       26863             3
# Sentiment_Polarity      float64            37432       26863          5410
# Sentiment_Subjectivity  float64            37432       26863          4474

# %% [markdown]
# * In App columns  number of null value is zero and the unique value is 1074.
# * In Translated_Review columns number of null values 26868   and unique value
#  is 27994.
# * In Sentiment ,Sentiment_Polarity and Sentiment_Subjectivity columns number of null values is same 26863 also the unique value is 3 in  Sentiment columns and simillary in Sentiment_Polarity columns number of unique value is 5410 and in sentiment _subjectivity columns number of unique value is 4474.

# %%
ur_df[ur_df['Translated_Review'].isnull()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %%
# Drop the NaN values in Translated_Review columns .
ur_df.dropna(subset=['Translated_Review'],inplace=True)

# %%
ur_df['Translated_Review'].shape
# Out:
# (37427,)

# %%
ur_df[ur_df['Sentiment'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %%
ur_df['Sentiment'].shape
# Out:
# (37427,)

# %%
ur_df[ur_df['Sentiment_Polarity'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %%
ur_df['Sentiment_Polarity'].shape
# Out:
# (37427,)

# %%
ur_df[ur_df['Sentiment_Subjectivity'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %%
ur_df['Sentiment_Subjectivity'].shape
# Out:
# (37427,)

# %%
ur_df.shape
# Out:
# (37427, 5)

# %% [markdown]
# * In above you can see all the Nan value drop in all columns.
# * There are a total of 37427 rows in the updated ur_df.

# %%
df.corr()
# Out:
#              index    Rating   Reviews      Size  Installs     Price
# index     1.000000 -0.113314 -0.095787 -0.077484 -0.106011 -0.008767
# Rating   -0.113314  1.000000  0.067587  0.062975  0.047600 -0.021158
# Reviews  -0.095787  0.067587  1.000000  0.180483  0.595748 -0.008999
# Size     -0.077484  0.062975  0.180483  1.000000  0.131708 -0.025740
# Installs -0.106011  0.047600  0.595748  0.131708  1.000000 -0.010567
# Price    -0.008767 -0.021158 -0.008999 -0.025740 -0.010567  1.000000

# %%
# Heat map for play_store
plt.figure(figsize = (20,10))
sns.heatmap(df.corr(), annot= True)
plt.title('Corelation Heatmap for Playstore Data', size=20)
# Out:
# Text(0.5, 1.0, 'Corelation Heatmap for Playstore Data')

# %% [markdown]
# * The` Price `is slightly negatively correlated with the `Rating, Reviews, and Installs.
# * The` Rating` is slightly positively correlated with the` Installs and Reviews` column.
# * The` installs` is slightly positively correlated with the` Rating and Reviews` column.

# %% [markdown]
# ### **know check co-relation in both the dataframes.**

# %%
merged_df = pd.merge(df, ur_df, on='App', how = "inner")

# %%
merged_dfinfo= pd.DataFrame(index=merged_df.columns)
merged_dfinfo['data_type'] = merged_df.dtypes
merged_dfinfo["count of non null values"] = merged_df.count()
merged_dfinfo['NaN values'] = merged_df.isnull().sum()
merged_dfinfo['unique_count'] = merged_df.nunique()
merged_dfinfo
# Out:
#                              data_type  count of non null values  NaN values  \
# index                            int64                     24069           0
# App                             object                     24069           0
# Category                        object                     24069           0
# Rating                         float64                     24069           0
# Reviews                          int64                     24069           0
# Size                           float64                     24069           0
# Installs                         int64                     24069           0
# Type                            object                     24069           0
# Price                          float64                     24069           0
# Content Rating                  object                     24069           0
# Genres                          object                     24069           0
# ...

# %%
merged_df.corr()
# Out:
#                            index    Rating   Reviews      Size  Installs  \
# index                   1.000000  0.011844 -0.008442  0.004946  0.099197
# Rating                  0.011844  1.000000  0.171095  0.167534  0.022414
# Reviews                -0.008442  0.171095  1.000000  0.430137  0.473094
# Size                    0.004946  0.167534  0.430137  1.000000  0.213743
# Installs                0.099197  0.022414  0.473094  0.213743  1.000000
# Price                   0.059421 -0.003789 -0.029231 -0.019786 -0.028292
# Sentiment_Polarity     -0.021535  0.091657 -0.108272 -0.159388 -0.081625
# Sentiment_Subjectivity -0.004293  0.072236 -0.007885  0.009185 -0.011639
#
#                            Price  Sentiment_Polarity  Sentiment_Subjectivity
# index                   0.059421           -0.021535               -0.004293
# Rating                 -0.003789            0.091657                0.072236
# Reviews                -0.029231           -0.108272               -0.007885
# ...

# %%
# Correlation heatmap
# Heat Map for the merged data frame
plt.figure(figsize = (15,10))
sns.heatmap(merged_df.corr(), annot= True, cmap='Greens')
plt.title(' Heatmap for merged Dataframe', size=20)
# Out:
# Text(0.5, 1.0, ' Heatmap for merged Dataframe')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
